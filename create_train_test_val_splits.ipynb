# %%
import os, random

# %%
# !mkdir val_images_64
# !mkdir val_images_128
# !mkdir test_images_64
# !mkdir test_images_128
# !mkdir train_images_64
# !mkdir train_images_128

# %%
for i in range(1, 4000):
    path = random.choice(os.listdir('train_images_128x128/'))
    print(path)
    os.rename("train_images_128x128/"+path, "4k_trains/test_"+str(i).zfill(5)+".png")
# Out:
# train_14427.png
# train_08579.png
# train_08764.png
# train_09622.png
# train_05535.png
# train_04176.png
# train_06036.png
# train_14611.png
# train_15936.png
# train_11423.png
# train_17472.png
# train_11584.png
# train_12711.png
# train_17643.png
# train_10135.png
# train_06377.png
# train_08632.png
# train_08217.png
# train_18396.png
# train_12890.png
# train_19534.png
# train_19127.png
# train_18681.png
# train_12998.png
# train_13762.png
# train_17557.png
# train_07243.png
# train_07333.png
# train_07748.png
# train_13383.png
# train_15685.png
# train_16228.png
# train_13457.png
# train_19451.png
# train_13062.png
# train_11684.png
# train_13940.png
# train_10665.png
# train_09200.png
# train_12594.png
# train_05548.png
# train_16420.png
# train_11779.png
# train_07687.png
# train_06641.png
# train_11254.png
# train_16706.png
# train_16528.png
# train_12208.png
# train_06668.png
# train_06859.png
# train_18209.png
# train_11350.png
# train_12436.png
# train_07134.png
# ...

# %%
for i in range(1, 20000):
    path = random.choice(os.listdir('images_128x128/'))
    if i < 2000:
        os.rename("images_128x128/"+path, "val_images_128x128/val_"+str(i).zfill(5)+".png")
        os.rename("images_64x64/"+path, "val_images_64x64/val_"+str(i).zfill(5)+".png")
    elif i < 4000:
        os.rename("images_128x128/"+path, "test_images_128x128/val_"+str(i).zfill(5)+".png")
        os.rename("images_64x64/"+path, "test_images_64x64/val_"+str(i).zfill(5)+".png")
    else:
        os.rename("images_128x128/"+path, "train_images_128x128/val_"+str(i).zfill(5)+".png")
        os.rename("images_64x64/"+path, "train_images_64x64/val_"+str(i).zfill(5)+".png")
# Out:
# 00003523_028.png
# 00008649_011.png
# 00000655_000.png
# 00005589_001.png
# 00007301_002.png
# 00007093_010.png
# 00000861_000.png
# 00000491_014.png
# 00006411_027.png
# 00006228_002.png
# 00005698_001.png
# 00007457_000.png
# 00002765_002.png
# 00008081_006.png
# 00003002_022.png
# 00000693_003.png
# 00006519_003.png
# 00003744_000.png
# 00003659_000.png
# 00001471_003.png
# 00005681_022.png
# 00008888_036.png
# 00000731_002.png
# 00003426_033.png
# 00001922_000.png
# 00006642_008.png
# 00000468_052.png
# 00008342_014.png
# 00003270_000.png
# 00007120_013.png
# 00008366_000.png
# 00004673_008.png
# 00005211_000.png
# 00009050_000.png
# 00005701_000.png
# 00003906_000.png
# 00000623_005.png
# 00004858_034.png
# 00007151_001.png
# 00000158_000.png
# 00003395_004.png
# 00004195_005.png
# 00000820_008.png
# 00006841_000.png
# 00008899_003.png
# 00007631_000.png
# 00001006_001.png
# 00000624_005.png
# 00005218_019.png
# 00003639_001.png
# 00003090_000.png
# 00005521_001.png
# ...

# %%
! ls images_128x128/ | grep 00000013_020
# Out:
# 00000013_020.png
