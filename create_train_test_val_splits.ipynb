# %%
import os, random

# %%
# !mkdir val_images_64
# !mkdir val_images_128
# !mkdir test_images_64
# !mkdir test_images_128

# %%
for i in range(1, 2000):
    path = random.choice(os.listdir('images_128x128/'))
    if i < 
    os.rename("images_128x128/"+path, "test_images_128x128/val_"+str(i).zfill(4)+".png")
    os.rename("images_64x64/"+path, "test_images_64x64/val_"+str(i).zfill(4)+".png")
# Out:
# 00003523_028.png
# 00008649_011.png
# 00000655_000.png
# 00005589_001.png
# 00007301_002.png
# 00007093_010.png
# 00000861_000.png
# 00000491_014.png
# 00006411_027.png
# 00006228_002.png
# 00005698_001.png
# 00007457_000.png
# 00002765_002.png
# 00008081_006.png
# 00003002_022.png
# 00000693_003.png
# 00006519_003.png
# 00003744_000.png
# 00003659_000.png
# 00001471_003.png
# 00005681_022.png
# 00008888_036.png
# 00000731_002.png
# 00003426_033.png
# 00001922_000.png
# 00006642_008.png
# 00000468_052.png
# 00008342_014.png
# 00003270_000.png
# 00007120_013.png
# 00008366_000.png
# 00004673_008.png
# 00005211_000.png
# 00009050_000.png
# 00005701_000.png
# 00003906_000.png
# 00000623_005.png
# 00004858_034.png
# 00007151_001.png
# 00000158_000.png
# 00003395_004.png
# 00004195_005.png
# 00000820_008.png
# 00006841_000.png
# 00008899_003.png
# 00007631_000.png
# 00001006_001.png
# 00000624_005.png
# 00005218_019.png
# 00003639_001.png
# 00003090_000.png
# 00005521_001.png
# ...

# %%
! ls images_128x128/ | grep 00000013_020
# Out:
# 00000013_020.png
